# %% [markdown]
# # EDA

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm

# %%
data_df = pd.read_excel("../../data/dataset.xlsx")
data_df = data_df.dropna()
data_df = data_df.reset_index(drop=True)
data_df = data_df.drop(columns=["Unnamed: 0"])
data_df.head()
# Out:
#              participant_id  collective  contrast  goal  goals2  list  \
# 0  5e1cf0eb65b6d3071f489de9        0.35      1.07  0.43    0.32  6.96
# 1  55d06fd334e9060012e5781c        0.30      0.67  0.30    0.20  2.83
# 2  615586b009f801c3f2d4af8d        0.18      0.74  0.16    0.26  3.40
# 3  5847e60f73170700013697c6        0.14      2.14  0.27    0.12  3.05
# 4  6086a11397234e7f83e4e793        0.90      4.76  0.86    0.22  7.92
#
#    metaphor  moral  question  story  ...  \
# 0      0.94   2.36      0.01   0.46  ...
# 1      0.71   0.22      0.01   0.60  ...
# 2      1.10   1.09      0.01   0.37  ...
# 3      0.49   0.46      0.00   1.09  ...
# 4      0.56   2.95      0.01   0.19  ...
#
#                                           final_text  overall_sentiment_all  \
# 0  Hello everyone. Thank you. Taking the time to ...               POSITIVE
# 1  Hi, I am Kathy. I'd love to be considered for ...                NEUTRAL
# 2  uh yeah I I think I would be the best candidat...               POSITIVE
# 3  Hello. Um I've of course a fair amount of expe...               POSITIVE
# 4  Okay, so I would like to thank you for giving ...               POSITIVE
#
#    positive_sentiment_all  negative_sentiment_all neutra_sentiment_all  \
# 0                  0.9569                  0.0007               0.0417
# 1                  0.1587                  0.0055               0.8350
# 2                  0.8051                  0.0164               0.1747
# 3                  0.5761                  0.1185               0.2484
# 4                  0.8515                  0.0016               0.1456
#
#   mixed_sentiment_all targets  text_length_all  prolific_score  \
# 0              0.0007    HIGH            771.0           100.0
# 1              0.0009     MED            424.0            99.0
# 2              0.0039     MED            449.0           100.0
# 3              0.0570    HIGH            611.0           100.0
# 4              0.0013    HIGH            611.0           100.0
#
#    prolific_indicator_all
# 0                       2
# 1                       2
# 2                       2
# 3                       2
# 4                       2
#
# [5 rows x 50 columns]

# %%
my_personality_df = pd.read_csv(
    "../../external_datasets/my_personality/my_personality.csv",
    encoding="ISO-8859-1",
)
my_personality_df = my_personality_df.dropna()
my_personality_df.head()
# Out:
#                             #AUTHID  \
# 0  b7b7764cfa1c523e4e93ab2a79a946c4
# 1  b7b7764cfa1c523e4e93ab2a79a946c4
# 2  b7b7764cfa1c523e4e93ab2a79a946c4
# 3  b7b7764cfa1c523e4e93ab2a79a946c4
# 4  b7b7764cfa1c523e4e93ab2a79a946c4
#
#                                               STATUS  sEXT  sNEU  sAGR  sCON  \
# 0                        likes the sound of thunder.  2.65   3.0  3.15  3.25
# 1  is so sleepy it's not even funny that's she ca...  2.65   3.0  3.15  3.25
# 2  is sore and wants the knot of muscles at the b...  2.65   3.0  3.15  3.25
# 3         likes how the day sounds in this new song.  2.65   3.0  3.15  3.25
# 4                                        is home. <3  2.65   3.0  3.15  3.25
#
#    sOPN cEXT cNEU cAGR cCON cOPN               DATE  NETWORKSIZE  BETWEENNESS  \
# 0   4.4    n    y    n    n    y  06/19/09 03:21 PM        180.0      14861.6
# 1   4.4    n    y    n    n    y  07/02/09 08:41 AM        180.0      14861.6
# 2   4.4    n    y    n    n    y  06/15/09 01:15 PM        180.0      14861.6
# 3   4.4    n    y    n    n    y  06/22/09 04:48 AM        180.0      14861.6
# 4   4.4    n    y    n    n    y  07/20/09 02:31 AM        180.0      14861.6
#
#    NBETWEENNESS  DENSITY  BROKERAGE  NBROKERAGE  TRANSITIVITY
# 0         93.29     0.03    15661.0        0.49           0.1
# 1         93.29     0.03    15661.0        0.49           0.1
# 2         93.29     0.03    15661.0        0.49           0.1
# 3         93.29     0.03    15661.0        0.49           0.1
# 4         93.29     0.03    15661.0        0.49           0.1

# %% [markdown]
# ## Target Variables

# %% [markdown]
# ### Main Dataset

# %%
targets = [
    "hones16",
    "emoti16",
    "extra16",
    "agree16",
    "consc16",
    "openn16",
]

labels = [
    "Honesty",
    "Emotional Stability",
    "Extroversion",
    "Agreeableness",
    "Conscientiousness",
    "Openness",
]

data_vars = data_df[targets].copy(deep=True)
data_vars.columns = labels
data_vars["Dataset"] = "IDIAP"
data_vars
# Out:
#       Honesty  Emotional Stability  Extroversion  Agreeableness  \
# 0     3.04170              3.66670       2.00000        3.50000
# 1     3.37500              3.50000       2.75000        3.00000
# 2     3.41670              3.29170       3.45830        3.41670
# 3     4.20830              1.87500       2.62500        3.70830
# 4     2.87500              2.58330       4.16670        2.95830
# ...       ...                  ...           ...            ...
# 1978  3.83333              3.16667       4.16667        4.04167
# 1979  2.54167              3.04167       3.25000        3.12500
# 1980  3.50000              2.25000       4.83333        4.25000
# 1981  3.79167              3.95833       3.62500        2.25000
# 1982  2.58333              3.87500       2.41667        1.45833
#
#       Conscientiousness  Openness Dataset
# 0               4.20830   3.12500   IDIAP
# 1               3.70830   3.12500   IDIAP
# 2               4.12500   4.16670   IDIAP
# 3               2.54170   3.58330   IDIAP
# 4               4.66670   4.04170   IDIAP
# ...                 ...       ...     ...
# 1978            3.79167   3.75000   IDIAP
# 1979            4.16667   3.33333   IDIAP
# 1980            4.66667   3.33333   IDIAP
# 1981            4.16667   3.54167   IDIAP
# 1982            3.20833   4.08333   IDIAP
#
# [1983 rows x 7 columns]

# %%
my_personality_targets = ["sEXT", "sNEU", "sAGR", "sCON", "sOPN"]

my_personality_labels = [
    "Extroversion",
    "Emotional Stability",
    "Agreeableness",
    "Conscientiousness",
    "Openness",
]

my_personality_vars = my_personality_df[my_personality_targets].copy(deep=True)
my_personality_vars.columns = my_personality_labels
my_personality_vars.loc[:, "Dataset"] = "My Personality"
my_personality_vars
# Out:
#       Extroversion  Emotional Stability  Agreeableness  Conscientiousness  \
# 0             2.65                 3.00           3.15               3.25
# 1             2.65                 3.00           3.15               3.25
# 2             2.65                 3.00           3.15               3.25
# 3             2.65                 3.00           3.15               3.25
# 4             2.65                 3.00           3.15               3.25
# ...            ...                  ...            ...                ...
# 9912          2.15                 2.15           4.10               2.90
# 9913          4.05                 3.35           3.80               3.95
# 9914          4.05                 3.35           3.80               3.95
# 9915          1.40                 4.05           3.30               3.40
# 9916          4.25                 3.00           3.25               3.50
#
#       Openness         Dataset
# 0         4.40  My Personality
# 1         4.40  My Personality
# 2         4.40  My Personality
# 3         4.40  My Personality
# 4         4.40  My Personality
# ...        ...             ...
# 9912      4.60  My Personality
# 9913      4.50  My Personality
# 9914      4.50  My Personality
# 9915      3.95  My Personality
# 9916      4.00  My Personality
#
# [9916 rows x 6 columns]

# %%
plt.figure()
sns.violinplot(data=data_df[targets], fill=False)
plt.xticks(range(6), labels)
plt.xticks(rotation=15)
plt.xticks(fontsize=11)
plt.yticks(fontsize=11)
plt.ylabel("Score")
plt.tight_layout()
plt.savefig("targets_violin.pdf", format="pdf")
plt.show()

# %%
shared_labels = [
    "Extroversion",
    "Emotional Stability",
    "Agreeableness",
    "Conscientiousness",
    "Openness",
    "Honesty",
]

joint_vars = pd.concat([data_vars, my_personality_vars], axis=0)[shared_labels + ["Dataset"]]
joint_vars = joint_vars.reset_index(drop=True)
joint_vars = joint_vars.melt(id_vars=["Dataset"], var_name="Trait", value_name="Score")

plt.figure()
sns.violinplot(data=joint_vars, x="Trait", y="Score", hue="Dataset", split=True, gap=.1, inner=None, fill=False, linewidth=2.5)
plt.xticks(range(6), shared_labels)
plt.xticks(rotation=30)
plt.xticks(fontsize=11)
plt.xlabel("")
plt.yticks(fontsize=11)
plt.ylim(0.5, 5.5)
plt.legend(title="Dataset", fontsize=9, loc="lower right", ncol=2)
plt.tight_layout()
plt.savefig("both_targets_violin.pdf", format="pdf")
plt.show()
